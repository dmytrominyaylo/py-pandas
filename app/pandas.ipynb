# %% [markdown]
# # Pandas

# %% [markdown]
# ## Task 1
#
# You should import the necessary libraries. You will use `numpy` and `pandas` libraries.
#
#
# > Don't forget to import `numpy`, and `pandas` in short form.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Task 2
#
# Create a `DataFrame` from the given dictionary `data`.

# %%
data = {
    "Name": ["John", "Emily", "Ryan"],
    "Age": [16, 28, 22],
    "City": ["New York", "Los Angeles", "Chicago"],
}

df = pd.DataFrame(data)
df
# Out:
#     Name  Age         City
# 0   John   16     New York
# 1  Emily   28  Los Angeles
# 2   Ryan   22      Chicago

# %% [markdown]
# ## Task 3
#
# In this task you should complete the following steps:

# %% [markdown]
# ### Task 3.1
# Display all data for `Age` column for the DataFrame you created in the previous task.

# %%
df.Age
# Out:
# 0    16
# 1    28
# 2    22
# Name: Age, dtype: int64

# %% [markdown]
# ### Task 3.2
#
# Add `Salary` column to the `DataFrame` with the values `[50000, 60000, 45000]`.

# %%
df["Salary"] = [50000, 60000, 45000]
df
# Out:
#     Name  Age         City  Salary
# 0   John   16     New York   50000
# 1  Emily   28  Los Angeles   60000
# 2   Ryan   22      Chicago   45000

# %% [markdown]
# ### Task 3.3
#
# Filter the `DataFrame` to show only the rows with the `Age` greater than 18.

# %%
df[df.Age > 18]
# Out:
#     Name  Age         City  Salary
# 1  Emily   28  Los Angeles   60000
# 2   Ryan   22      Chicago   45000

# %% [markdown]
# ## Task 4
#
# In this task you should complete the following steps:

# %% [markdown]
# ### Task 4.1
#
# Add new calculated field `Birth year`;

# %%
df["Birth year"] = 2025 - df.Age
df
# Out:
#     Name  Age         City  Salary  Birth year
# 0   John   16     New York   50000        2009
# 1  Emily   28  Los Angeles   60000        1997
# 2   Ryan   22      Chicago   45000        2003

# %% [markdown]
# ### Task 4.2
#
# Add new calculated field `Average age`.

# %%
df["Average age"] = df.Age.mean()
df
# Out:
#     Name  Age         City  Salary  Birth year  Average age
# 0   John   16     New York   50000        2009         22.0
# 1  Emily   28  Los Angeles   60000        1997         22.0
# 2   Ryan   22      Chicago   45000        2003         22.0

# %% [markdown]
# ### Task 4.3
#
# Calculate absolute difference between `Age` and `Average age`.

# %%
df["Age diff"] = (df.Age - df["Average age"]).abs()
df
# Out:
#     Name  Age         City  Salary  Birth year  Average age  Age diff
# 0   John   16     New York   50000        2009         22.0       6.0
# 1  Emily   28  Los Angeles   60000        1997         22.0       6.0
# 2   Ryan   22      Chicago   45000        2003         22.0       0.0

# %% [markdown]
# ## Task 5
#
# Complete the following tasks described below.

# %% [markdown]
# ### Task 5.1
#
# You have two dictionaries `data1` and `data2`. Create two `DataFrame` objects from these dictionaries. Then, `concatenate`, and `merge` these two `DataFrame` objects into one `DataFrame` object, and see the difference.

# %%
# Data
data1 = {'Name': ['John', 'Emily', 'Ryan'],
         'Age': [25, 28, 22]}
data2 = {'Name': ['Emily', 'Ryan', 'Mike'],
         'City': ['Los Angeles', 'Chicago', 'Houston']}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

# %%
pd.merge(df1, df2, how="inner")
# Out:
#     Name  Age         City
# 0  Emily   28  Los Angeles
# 1   Ryan   22      Chicago

# %%
pd.concat([df1, df2])
# Out:
#     Name   Age         City
# 0   John  25.0          NaN
# 1  Emily  28.0          NaN
# 2   Ryan  22.0          NaN
# 0  Emily   NaN  Los Angeles
# 1   Ryan   NaN      Chicago
# 2   Mike   NaN      Houston

# %% [markdown]
# ### Task 5.2
#
# You have two `Series` objects `s1` and `s2`. Make default mathematical operations on these two `Series` objects. Such as `+`, `-`, `*`, `/`, `**`, `//`, `%`. Also, filter `s1` and print only even numbers, and `s2` only with odd numbers.

# %%
s1 = pd.Series([1, 2, 3, 4, 5])
s2 = pd.Series([6, 7, 8, 9, 10])

# %%
s1 + s2
# Out:
# 0     7
# 1     9
# 2    11
# 3    13
# 4    15
# dtype: int64

# %%
s1 - s2
# Out:
# 0   -5
# 1   -5
# 2   -5
# 3   -5
# 4   -5
# dtype: int64

# %%
s1 * s2
# Out:
# 0     6
# 1    14
# 2    24
# 3    36
# 4    50
# dtype: int64

# %%
s1 / s2
# Out:
# 0    0.166667
# 1    0.285714
# 2    0.375000
# 3    0.444444
# 4    0.500000
# dtype: float64

# %%
s1 ** s2
# Out:
# 0          1
# 1        128
# 2       6561
# 3     262144
# 4    9765625
# dtype: int64

# %%
s1 // s2
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# dtype: int64

# %%
s1 % s2
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s1[s1 % 2 == 0]
# Out:
# 1    2
# 3    4
# dtype: int64

# %%
s2[s2 % 2 == 1]
# Out:
# 1    7
# 3    9
# dtype: int64

# %% [markdown]
# ### Task 5.3
#
# You have a `Serias` object `s`. Make the following operations on this `Series` object:
#
# * make all words in uppercase without loops;
# * get length of each word without loops.

# %%
s = pd.Series(["numpy", "pandas", "matplotlib"])

# %%
s.str.upper()
# Out:
# 0         NUMPY
# 1        PANDAS
# 2    MATPLOTLIB
# dtype: object

# %%
s.str.len()
# Out:
# 0     5
# 1     6
# 2    10
# dtype: int64

# %% [markdown]
# ## Task 6 Optional
#
# You have a large dataset consisting of a series of numbers. Your task is to calculate the moving average of the series using a window of `5` elements. The moving average is the average of a set of consecutive values in the series, where the window `slides` through the series to compute the average at each position. The goal is to calculate the moving average efficiently and accurately. Also, compare time performance of Python and Pandas solutions.
#
# > Please, note: If you get `nan` while calculating the moving average, you should remove it from the result. Pandas solution should take 1-2 lines of code.

# %% [markdown]
# ### Python Solution
#
# In the Python solution, a large dataset is generated using random numbers. The moving average is computed by iterating over the dataset using a loop. At each position, a window of 5 elements is created, and the average is calculated by summing the values in the window and dividing by 5.

# %%
import random

def unknown_signature():
    # Generate a large dataset
    data = [random.randint(1, 100) for _ in range(10000000)]

    # Calculate the moving average with a window of 5
    moving_averages = []
    for i in range(4, len(data)):
        window = data[i - 4 : i + 1]
        average = sum(window) / 5
        moving_averages.append(average)
    return moving_averages[:10]

# %time unknown_signature()
# Out:
# CPU times: total: 8.8 s
# Wall time: 9.94 s
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[88], line 15
#      12         moving_averages.append(average)
#      13     return moving_averages[:10]
# ---> 15 get_ipython().run_line_magic('time', 'unknown_signature()')
#
# File C:\MyProject\venv\py-pandas\Lib\site-packages\IPython\core\interactiveshell.py:2504, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2502     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2503 with self.builtin_trap:
# -> 2504     result = fn(*args, **kwargs)
#    2506 # The code below prevents the output from being displayed
#    2507 # when using magics with decorator @output_can_be_silenced
#    2508 # when the last Python token in the expression is a ';'.
#    2509 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File C:\MyProject\venv\py-pandas\Lib\site-packages\IPython\core\magics\execution.py:1452, in ExecutionMagics.time(self, line, cell, local_ns)
#    1450 if interrupt_occured:
#    1451     if exit_on_interrupt and captured_exception:
# -> 1452         raise captured_exception
#    1453     return
#    1454 return out
#
# File C:\MyProject\venv\py-pandas\Lib\site-packages\IPython\core\magics\execution.py:1402, in ExecutionMagics.time(self, line, cell, local_ns)
#    1400 st = clock2()
#    1401 try:
# -> 1402     out = eval(code, glob, local_ns)
#    1403 except KeyboardInterrupt as e:
#    1404     captured_exception = e
#
# File <timed eval>:1
#
# Cell In[88], line 11, in unknown_signature()
#       9 for i in range(4, len(data)):
#      10     window = data[i - 4 : i + 1]
# ---> 11     average = sum(window) / 5
#      12     moving_averages.append(average)
#      13 return moving_averages[:10]
#
# TypeError: 'Series' object is not callable

# %% [markdown]
# ### Solution using Pandas and Numpy

# %%
data = np.random.rand(1_000_000)
# %time pd.Series(data).rolling(window=5).mean().dropna().values
# Out:
# CPU times: total: 93.8 ms
# Wall time: 102 ms
# array([0.72292675, 0.76984209, 0.63296869, ..., 0.48299201, 0.62737452,
#        0.64953458], shape=(999996,))
